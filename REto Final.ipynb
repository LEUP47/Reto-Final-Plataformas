# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfa=pd.read_csv("listingsAmsterdam.csv")
dfa.head()
dfp=pd.read_csv("listingsPorto.csv")
dfp.head()
# Out:
#                     id                                       listing_url  \
# 0             45168099             https://www.airbnb.com/rooms/45168099
# 1   859387906570209474   https://www.airbnb.com/rooms/859387906570209474
# 2             44059520             https://www.airbnb.com/rooms/44059520
# 3  1171570720720407183  https://www.airbnb.com/rooms/1171570720720407183
# 4   952203316395069110   https://www.airbnb.com/rooms/952203316395069110
#
#         scrape_id last_scraped       source                           name  \
# 0  20240617171802   2024-06-17  city scrape    Beach & Walkways GuestHouse
# 1  20240617171802   2024-06-17  city scrape               Estúdio Canidelo
# 2  20240617171802   2024-06-18  city scrape        Estudio centro do Porto
# 3  20240617171802   2024-06-17  city scrape         Luz&Martins Alojamento
# 4  20240617171802   2024-06-17  city scrape  Cama 5 em Dormitório Feminino
#
#                                          description  \
# ...

# %% [markdown]
# ***Empezamos con Amsterdam***

# %%
#Separamos por columnas cualitativas y cuantitativas
cuanti=dfa.select_dtypes(include=['number'])
cuanli=dfa.select_dtypes(include=['object'])

# %%
cuanti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9310 entries, 0 to 9309
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9310 non-null   int64
#  1   scrape_id                                     9310 non-null   int64
#  2   host_id                                       9310 non-null   int64
#  3   host_listings_count                           9310 non-null   int64
#  4   host_total_listings_count                     9310 non-null   int64
#  5   neighbourhood_group_cleansed                  0 non-null      float64
#  6   latitude                                      9310 non-null   float64
#  7   longitude                                     9310 non-null   float64
#  8   accommodates                                  9310 non-null   int64
# ...
